# %%
#Library includes
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow, figure
import numpy as np
from scipy import ndimage, misc
import scipy.ndimage
#import scipy.ndimage as scipy
from PIL import Image
import cv2
import math
import os
import glob
#from pylsd import lsd
import sys
from utils import resize, grayscale, showimage, dilate, gaussian_blur, laplace, sobel
# %matplotlib inline

# Global variables
#gray_scale_images = "/home/user/devel/python.assignments/notebooks"
source_directory = "images"
output_directory = "image_output"
# Global variables for the laplace function
ddepth = cv2.CV_16S
kernel_size = 3

os.listdir("images/")
# Out:
# ['utm_00001.jpg', 'canny1.jpg', 'utm_00000.mask.png']

# %%
#reading in an image
input_images = [cv2.imread(img_path)  for img_path in glob.glob("images/*")]

# %%
grayscaled_image = grayscale(input_images[0])
resized_image = resize(grayscaled_image, (200, 200))
sobel_image = sobel(resized_image)
showimage(sobel_image, cmap="gray")

# %%
sobel_image2 = sobel(sobel_image, axis=0)
showimage(sobel_image2, cmap="gray")
