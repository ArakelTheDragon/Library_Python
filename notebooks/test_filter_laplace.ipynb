# %%
#Library includes
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow, figure
import numpy as np
from scipy import ndimage, misc
import scipy.ndimage
#import scipy.ndimage as scipy
from PIL import Image
import cv2
import math
import os
import glob
#from pylsd import lsd
import sys
from utils import resize, grayscale, showimage, dilate, gaussian_blur, laplace
# %matplotlib inline

# Global variables

# %%
os.listdir("images/")
# Out:
# ['utm_00001.jpg', 'canny1.jpg', 'utm_00000.mask.png']

# %%
#reading in an image
input_images = [cv2.imread(img_path)  for img_path in glob.glob("images/*")]

# %%
grayscaled_image = grayscale(input_images[2])
resized_image = resize(grayscaled_image, (200, 200))
laplaced_image = laplace(resized_image)
showimage(laplaced_image, cmap="gray")
