# %%
import os, json, yaml, math
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt

# %%
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.rcParams['figure.figsize'] = [10, 5]

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
fig, axes = plt.subplots(3, 1, sharex=True, figsize=(20,7))
axes[0].plot(x, x)
axes[0].set_title('X Raw Data', size=22)
axes[1].plot(x, np.cos(x))
axes[1].set_title('CosX Data', size=22)
axes[2].plot(x, np.sin(x))
axes[2].set_title('SinX Data', size=22)
# Out:
# Text(0.5, 1.0, 'SinX Data')

# %%
# display image by IPython
from IPython.display import Image 
pil_img = Image(filename='target/02_mandelbrot.png')
display(pil_img)
# Out:
# --------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-16-98313d779706> in <module>
#       1 # display image by IPython
#       2 from IPython.display import Image
# ----> 3 pil_img = Image(filename='target/02_mandelbrot.png')
#       4 display(pil_img)
#
# ~/anaconda3/envs/testing/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1222         self.retina = retina
#    1223         self.unconfined = unconfined
# -> 1224         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1225                 metadata=metadata)
#    1226
#
# ~/anaconda3/envs/testing/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     628             self.metadata = {}
#     629
# --> 630         self.reload()
#     631         self._check_data()
#     632
#
# ~/anaconda3/envs/testing/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#    1254         """Reload the raw data from file or URL."""
#    1255         if self.embed:
# -> 1256             super(Image,self).reload()
#    1257             if self.retina:
#    1258                 self._retina_shape()
#
# ~/anaconda3/envs/testing/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#     653         """Reload the raw data from file or URL."""
#     654         if self.filename is not None:
# --> 655             with open(self.filename, self._read_flags) as f:
#     656                 self.data = f.read()
#     657         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'target/02_mandelbrot.png'

# %%
# display image by Pillow
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('target/02_mandelbrot.png', 'r')
imshow(np.asarray(pil_im))
# Out:
# --------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-17-4b870f185782> in <module>
#       5
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 7 pil_im = Image.open('target/02_mandelbrot.png', 'r')
#       8 imshow(np.asarray(pil_im))
#
# ~/anaconda3/envs/testing/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: 'target/02_mandelbrot.png'

# %%
# display image by opencv
from matplotlib import pyplot as plt
import numpy as np
import cv2

img = cv2.imread('target/02_mandelbrot.png')
img2 = img[:,:,::-1]
plt.imshow(img)

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);
