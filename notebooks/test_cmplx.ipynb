# %%
                                                    # Library includes
import os, json, yaml, math
import cmath                                        # Importing cmath for complex number operations
import pandas as pd
import numpy as np
from numpy import newaxis
import matplotlib .pyplot as plt
from matplotlib .pyplot import imshow
import array
from array import array
from IPython.display import Image
import PIL
#from PIL import Image
import random                                       # The library provides the ability to create random tupples

                                                    # Global variables
                                                    # These variables can be used in all functions, in Python
                                                    # all global and local variables must be manually initialized,
                                                    # its recommended to move all global variables to a separate
                                                    # file

ErrorCode_OK = 0                                    # Everything is ok
#RandomTuple = list []                              # Define the RandomTuple as a list with unknow number,
                                                    # a tupple is immutable, a list is mutable

a = [[2, 3]]                                        # Use a double(2D) array
    
#def TestCycles ():
#                                                    # Local variables and initialization
#                                                    # Requires the libraries:
#                                                    # none
#                
#    global a                                        # In order to use a global variable in Python
#                                                    # it must be declared as gloabl inside of the function
#        
#    for i in range (0, 98, 1):                      # for (i = 0; i < 98, i+1)
#        a.append([random.random ()*20-10, random.random ()*20-10]) # Create an array with tuples
#        test_complex (a[i][0], a[i][1])
#        #print (a [i])                               # print the RandomTuple
#        
#    return ErrorCode_OK

def test_complex ():
                                                    # Local variables and initialization
                                                    # Requires the following libraries:
                                                    # import cmath
                                                    # import math
                    
    #c1 = complex (2, 3)                             # Create a complex number 2 + 3j
    #c2 = complex (3, 4)                             # Create a complex number 3 + 4j
    
    #a = [[2, 3]]                                   # Use either the global variable or the local one
                                                    # Processing
    #for i in range (0, 98, 1):                      # run a cycle from 0 to 98 with a step of 1
        #TestCycles ()
    a.append ([random.random ()*20-10, random.random ()*20-10])
    cmplx (1, 2)                                # Return the complex and imaginary part of a number
    cmplx_add (a[0][0], a[0][1])                              
    cmplx_abs (a[0][0]])
    cmplx_mult (a[0][0], a[0][1])
    cmplx_square (a[0])
    
                                                    # Reporting
    return 0                                        # Everything is ok

def cmplx (real, im):                               # There is no function in cmath to do this
                                                    # Local variables and initialization
                                                    # Requires the libraries:
                                                    # none
                                                    
                                                    # Processing
    print ("DEBUG: Python complex = ")              # A statement only for debugging the function
    ComplexNumber = complex (real, im)              # record the complex number in ComplexNumber
    print (ComplexNumber)                           # print the ComplexNumber variable
    print ("DEBUG: self-made cmplx = ")             # A statement only for debugging the function
    ComplexNumber = real, im
    print (str(real) + " + " + str(im) + "j")
                                                    # Reporting
    return ComplexNumber                            # Returns the complex number in format real, im

def cmplx_add (c1, c2):
                                                    # Local variables and initialization
                                                    # Requires the libraries:
                                                    # import cmath
                                                    # import math
    
                                                    # Processing
    print ("DEBUG: Python complex = ")              # A statement only for debugging the function
    ComplexNumber = c1 + c2                         # Sum the 2 complex numbers
    print (ComplexNumber)                           # print the complex number
    
    print ("DEBUG: self-made cmplx_add = ")
    ComplexNumber = c1.real + c2.real, c1.imag + c2.imag# Sum the complex number
    print (ComplexNumber)                           # print the complex number

    #return (c1[0]+c1[1],c1[1]+c2[1])               # Does not work as the object is not subscribtable
    return ComplexNumber                            # Return the complex number

def cmplx_abs (c1):
                                                    # Local variables and initialization
                                                    # Requires the libraries:
                                                    # import cmath
                                                    # import math
                    
                                                    # Processing
    print ("DEBUG: Python complex = ")              # A statement only for debugging the function
    ComplexNumber = abs (c1)                        # Calculate the square root(absolute value) of the complex number
    print (ComplexNumber)

    print ("DEBUG: self-made cmplx_abs = ")
    ComplexNumber = math.sqrt (pow(c1.real, 2) + pow(c1.imag, 2)) # Calculate the square root of the complex number
    print (ComplexNumber)                           # print the square root(absolute value) of the complex number
    
                                                    # Reporting
    return ComplexNumber                            # Return the square root(absolute value) of the complex number
    #return math.sqrt(c1[0]*c1[0] + c1[1]*c1[1])    # Does not work as the object is not subscribtable

def cmplx_mult (c1, c2):
                                                    # Local variables and initialization
                                                    # Requires the libraries:
                                                    # import cmath
                                                    # import math
    #a, b = c1                                      # Does not work, can not unpack non-iterable complex object
    #c, d = c2                                      # Does not work, can not unpack non-iterable complex object
    a = c1.real
    b = c1.imag
    c = c2.real
    d = c2.imag
    
                                                    # Processing
    print ("DEBUG: Python complex = ")              # A statement only for debugging the function
    ComplexNumber = c1 * c2                         # Calculate the complex number
    print (ComplexNumber)                           # print the ComplexNumber
    
    print ("DEBUG: self madecmplx_mult = ")         # A statement only for debugging the function
    ComplexNumber = (a*c)-(b*d), (b*c)+(a*d)        # Calculate the complex number, there is a minus here,
                                                    # because the (square root of -1) on the power of 2 is -1
                                                    # j on the power of 2 = -1
    print (ComplexNumber)                           # print the ComplexNumber
    
                                                    # Reporting
    return ComplexNumber                            # Return the ComplexNumber as the result of the function
 
def cmplx_square (c1):
                                                    # Local variables and initialization
                                                    # Requires the libraries
                                                    # import cmath
                                                    # import math
                    
                                                    # Processing
    print ("DEBUG: Python complex = ")              # A statement only for debugging the function
    ComplexNumber = c1 * c1                         # Multiply the complex number by iteself
    print (ComplexNumber)
    
    print ("DEBUG: self-made cmplx_square calls the self-made cmplx_mult = ")# A statement only for debugging the function
    ComplexNumber = cmplx_mult (c1, c1)             # Calculate the ComplexNumber
    print (ComplexNumber)                           # print the ComplexNumber
    
                                                    # Reporting                        
    return ComplexNumber                            # return the ComplexNumber as a result of the function

# %%
if __name__ == "__main__":
    for i in range (0, 98, 1):                      # create a cycle from 0 to 98 with a step 1
        test_complex(a[i][0], a[i][1])
# Out:
# DEBUG: Python complex =
# (1+2j)
# DEBUG: self-made cmplx =
# 1 + 2j
# DEBUG: Python complex =
# 5
# DEBUG: self-made cmplx_add =
# (5, 0)
# DEBUG: Python complex =
# 2
# DEBUG: self-made cmplx_abs =
# 2.0
# DEBUG: Python complex =
# 6
# DEBUG: self madecmplx_mult =
# (6, 0)
# DEBUG: Python complex =
# 4
# DEBUG: self-made cmplx_square calls the self-made cmplx_mult =
# DEBUG: Python complex =
# 4
# DEBUG: self madecmplx_mult =
# (4, 0)
# (4, 0)
# DEBUG: Python complex =
# (1+2j)
# DEBUG: self-made cmplx =
# 1 + 2j
# DEBUG: Python complex =
# 14.441880759080146
# DEBUG: self-made cmplx_add =
# (14.441880759080146, 0.0)
# DEBUG: Python complex =
# 8.700643373401412
# DEBUG: self-made cmplx_abs =
# 8.700643373401412
# DEBUG: Python complex =
# 49.95245901483012
# DEBUG: self madecmplx_mult =
# (49.95245901483012, 0.0)
# DEBUG: Python complex =
# 75.7011951111139
# DEBUG: self-made cmplx_square calls the self-made cmplx_mult =
# DEBUG: Python complex =
# 75.7011951111139
# ...
